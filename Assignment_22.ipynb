# %% [markdown]
# 1. What is the result of the code, and explain?
#
#
# >>> X = 'iNeuron'
# >>> def func():
# print(X)
#
#
# >>> func()
#
#
# 2. What is the result of the code, and explain?
#
#
# >>> X = 'iNeuron'
# >>> def func():
# X = 'NI!'
#
#
# >>> func()
# >>> print(X)
#
#
# 3. What does this code print, and why?
#
#
# >>> X = 'iNeuron'
# >>> def func():
# X = 'NI'
# print(X)
#
#
# >>> func()
# >>> print(X)
#
#
# 4. What output does this code produce? Why?
#
#
# >>> X = 'iNeuron'
# >>> def func():
# global X
# X = 'NI'
#
#
# >>> func()
# >>> print(X)
#
#
# 5. What about this code—what’s the output, and why?
#
#
# >>> X = 'iNeuron'
# >>> def func():
# X = 'NI'
# def nested():
# print(X)
# nested()
#
#
# >>> func()
# >>> X
#
#
# 6. How about this code: what is its output in Python 3, and explain?
#
#
# >>> def func():
# X = 'NI'
# def nested():
# nonlocal X
# X = 'Spam'
# nested()
# print(X)
#
#
# >>> func()

# %% [markdown]
# <!-- 1. What is the result of the code, and explain?
#
#
# >>> X = 'iNeuron'
# >>> def func():
# print(X)
#
#
# >>> func() -->

# %% [markdown]
# 1. What is the result of the code, and explain?
#
#
# >>> X = 'iNeuron'
# >>> def func():
# print(X)
#
#
# >>> func()
#
# Answer - iNeuron
#
# x is a global variable So it can be used anywhere in the program in function or in class

# %% [markdown]
# 2. What is the result of the code, and explain?
#
#
# >>> X = 'iNeuron'
# >>> def func():
# X = 'NI!'
#
#
# >>> func()
# >>> print(X)
#
# Answer- iNeuron
#
# here print function took the global variable as well as x is the string object so it is immutable therefore the scope of immutable local variable will be within the function and outside the function global variable remain unchanged

# %% [markdown]
# 3. What does this code print, and why?
#
#
# >>> X = 'iNeuron'
# >>> def func():
# X = 'NI'
# print(X)
#
#
# >>> func()
# >>> print(X)
#
# Answer- NI!
#         iNeuron
#
# Here first it print local variable and second time it print global variable

# %% [markdown]
# 4. What output does this code produce? Why?
#
#
# >>> X = 'iNeuron'
# >>> def func():
# global X
# X = 'NI'
#
#
# >>> func()
# >>> print(X)
#
# Answer - NI!
#
# Here Before assigning variable we have mentioned the global therefore x become global variable and scope of global variable is everywhere in program

# %% [markdown]
# 5. What about this code—what’s the output, and why?
#
#
# >>> X = 'iNeuron'
# >>> def func():
# X = 'NI'
# def nested():
# print(X)
# nested()
#
#
# >>> func()
# >>> X
#
# Answer - NI!
#         iNeuron
#
# Here first output is local variable and second output is global variable i.e., when we called the function value of "NI!" assign  to x and this value printing inside the nested function and after the execution the value of x remain unchanged and displayed the global value

# %% [markdown]
# 6. How about this code: what is its output in Python 3, and explain?
#
# >>> def func():
# X = 'NI'
# def nested():
# nonlocal X
# X = 'Spam'
# nested()
# print(X)
#
# >>> func()
#
# Answer-Spam
#
# Here the output is Spam as nonlocal keyword is used to work with variables inside nested functions, where the variable should not belong to the inner function. and variable can be used nonlocal in entire function but the scope of nonlocal variable is within the function and can not be used as a global variable
